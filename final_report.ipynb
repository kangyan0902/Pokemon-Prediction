# %% [markdown]
# # Stats 131 Final Report
# ## Pokemon Dataset
# <p class="c1"><span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p>
#
# *Zheng Wang, Yan Kang, Citina Liang*
#
# *December 2nd, 2018*

# %% [markdown]
# <h1 class="c17" id="h.o5k2spmnseeg"><span>Introduction</span></h1>
# <p class="c1"><span class="c2">This study used the Pokemon dataset to explore the relationship between Pokemon legendary status, generation, having combined types or not, types and their abilities attributes (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed). Our investigation of the data is in 4 steps: </span></p>
# <p class="c1"><span class="c2">1. Exploring and visualizing the relationships of desired variables</span></p>
# <p class="c1"><span class="c2">2. Preprocessing the dataset for modeling</span></p>
# <p class="c1"><span class="c2">3. Choosing a classification model suitable to our goal and dataset (Random Forest)</span></p>
# <p class="c1"><span class="c2">4. Optimizing the model using hyperparameter tuning (we use TPOT optimization)</span></p>
# <!-- add a blanck line -->
# <p class="c1"><span class="c2">The link to our presentation video is: <a href="https://youtu.be/vjR8euS0DVQ">https://youtu.be/vjR8euS0DVQ</a></span></p>
# <p class="c1"><span class="c2">The link to our dataset is: <a href="https://www.kaggle.com/abcsds/pokemon">https://www.kaggle.com/abcsds/pokemon</a></span></p>
# <p class="c1 c4"><span class="c2"></span></p><p class="c1"><span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p>
#
# <hr> <!-- add a sperating line -->

# %% [markdown]
# <html><head><meta content="text/html; charset=UTF-8" http-equiv="content-type"><style type="text/css">ul.lst-kix_wj1umudc65o3-8{list-style-type:none}ul.lst-kix_wj1umudc65o3-6{list-style-type:none}ul.lst-kix_wj1umudc65o3-7{list-style-type:none}ul.lst-kix_wj1umudc65o3-4{list-style-type:none}ul.lst-kix_wj1umudc65o3-5{list-style-type:none}ul.lst-kix_wj1umudc65o3-2{list-style-type:none}ul.lst-kix_wj1umudc65o3-3{list-style-type:none}ul.lst-kix_wj1umudc65o3-0{list-style-type:none}ul.lst-kix_wj1umudc65o3-1{list-style-type:none}ul.lst-kix_9gu4atwo5n7d-0{list-style-type:none}.lst-kix_wj1umudc65o3-6>li:before{content:"\0025cf  "}.lst-kix_wj1umudc65o3-7>li:before{content:"\0025cb  "}ul.lst-kix_9gu4atwo5n7d-2{list-style-type:none}ul.lst-kix_9gu4atwo5n7d-1{list-style-type:none}.lst-kix_9gu4atwo5n7d-8>li:before{content:"\0025a0  "}.lst-kix_wj1umudc65o3-4>li:before{content:"\0025cb  "}.lst-kix_wj1umudc65o3-5>li:before{content:"\0025a0  "}.lst-kix_wj1umudc65o3-8>li:before{content:"\0025a0  "}.lst-kix_9gu4atwo5n7d-7>li:before{content:"\0025cb  "}.lst-kix_9gu4atwo5n7d-1>li:before{content:"\0025cb  "}.lst-kix_9gu4atwo5n7d-0>li:before{content:"\0025cf  "}.lst-kix_9gu4atwo5n7d-2>li:before{content:"\0025a0  "}.lst-kix_9gu4atwo5n7d-3>li:before{content:"\0025cf  "}.lst-kix_wj1umudc65o3-0>li:before{content:"\0025cf  "}.lst-kix_wj1umudc65o3-1>li:before{content:"\0025cb  "}ul.lst-kix_9gu4atwo5n7d-8{list-style-type:none}.lst-kix_wj1umudc65o3-2>li:before{content:"\0025a0  "}.lst-kix_wj1umudc65o3-3>li:before{content:"\0025cf  "}ul.lst-kix_9gu4atwo5n7d-7{list-style-type:none}.lst-kix_9gu4atwo5n7d-4>li:before{content:"\0025cb  "}.lst-kix_9gu4atwo5n7d-6>li:before{content:"\0025cf  "}ul.lst-kix_9gu4atwo5n7d-4{list-style-type:none}ul.lst-kix_9gu4atwo5n7d-3{list-style-type:none}ul.lst-kix_9gu4atwo5n7d-6{list-style-type:none}.lst-kix_9gu4atwo5n7d-5>li:before{content:"\0025a0  "}ul.lst-kix_9gu4atwo5n7d-5{list-style-type:none}ol{margin:0;padding:0}table td,table th{padding:0}.c0{margin-left:36pt;padding-top:0pt;padding-left:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c11{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:16pt;font-family:"Arial";font-style:normal}.c9{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Arial";font-style:normal}.c10{color:#666666;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:12pt;font-family:"Arial";font-style:normal}.c14{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:11pt;font-family:"Times New Roman";font-style:normal}.c15{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:20pt;font-family:"Arial";font-style:normal}.c2{color:#000000;font-weight:400;text-decoration:none;vertical-align:baseline;font-size:12pt;font-family:"Times New Roman";font-style:normal}.c13{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:center}.c1{padding-top:0pt;padding-bottom:0pt;line-height:1.15;orphans:2;widows:2;text-align:left}.c17{padding-top:20pt;padding-bottom:6pt;line-height:1.5;page-break-after:avoid;text-align:left}.c12{padding-top:18pt;padding-bottom:6pt;line-height:1.15;page-break-after:avoid;text-align:left}.c20{padding-top:14pt;padding-bottom:4pt;line-height:1.15;page-break-after:avoid;text-align:left}.c5{-webkit-text-decoration-skip:none;color:#1155cc;text-decoration:underline;text-decoration-skip-ink:none}.c7{background-color:#ffffff;max-width:468pt;padding:72pt 72pt 72pt 72pt}.c3{font-size:12pt;font-family:"Times New Roman";font-weight:400}.c18{color:#000000;text-decoration:none;vertical-align:baseline}.c23{font-size:24pt;font-style:normal}.c24{font-size:18pt;font-style:normal}.c16{color:inherit;text-decoration:inherit}.c19{font-family:"Times New Roman";font-weight:400}.c22{padding:0;margin:0}.c21{color:#000000}.c4{height:11pt}.c6{font-style:italic}.c8{text-indent:36pt}.title{padding-top:0pt;color:#000000;font-size:26pt;padding-bottom:3pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}.subtitle{padding-top:0pt;color:#666666;font-size:15pt;padding-bottom:16pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}li{color:#000000;font-size:11pt;font-family:"Arial"}p{margin:0;color:#000000;font-size:11pt;font-family:"Arial"}h1{padding-top:20pt;color:#000000;font-size:20pt;padding-bottom:6pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h2{padding-top:18pt;color:#000000;font-size:16pt;padding-bottom:6pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h3{padding-top:16pt;color:#434343;font-size:14pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h4{padding-top:14pt;color:#666666;font-size:12pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h5{padding-top:12pt;color:#666666;font-size:11pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;orphans:2;widows:2;text-align:left}h6{padding-top:12pt;color:#666666;font-size:11pt;padding-bottom:4pt;font-family:"Arial";line-height:1.15;page-break-after:avoid;font-style:italic;orphans:2;widows:2;text-align:left}</style><h1 class="c17" id="h.ee7nj3s2qz7a"><span class="c15">Background Information</span></h1><p class="c1 c8"><span class="c2">The Pokemon dataset includes all stats of each specific Pokemon from generation 1 through generation 6. Pokemon, also known as pocket monsters, were originally coming from a Japanese video game series. The game was firstly created in Japan in 1996, and it became international in 1999. Now, it is better known as an animated series which is popular all over the world. Pokemon are created monsters that can be captured by a tool called Pokeball which is used to store Pokemon. Before they are captured, they are living mostly in the forest and allow all Pokemon masters to capture them. In order to capture Pokemon, each Pokemon master will use their existing Pokemon to defeat them. After Pokemon are successfully being captured, they will be loyal to the game player or the character. In addition, once Pokemon were captured, they will not able to be captured again unless the owner wants to release them. They are able to fight with other Pokemon for gaining experience in order for leveling up or even evolving. Each level gained will increase stats such as Hit Points, attack strength or defense strength. You will expect a significant increase after your Pokemon&rsquo;s evolution. Evolution, such as Charmander will evolve to Charmeleon, is a unique feature in this game series which the Pokemon will change its look after evolution as well as enhancing its ability. This dataset included both primitive Pokemon and evolved Pokemon. There are currently 7 generations of Pokemon, and this dataset includes all Pokemon that can be collected for the first 6 generations. In each generation, there will be some new Pokemon are added to the total collection of Pokemon.</span></p><h2 class="c12" id="h.d8o9wzgo9rmh"><span class="c11">Data Description</span></h2><p class="c1"><span class="c2">This dataset includes 800 observations and 12 variables</span></p><h4 class="c20" id="h.2888cmz2c4eh"><span class="c21">Variable Description</span><span class="c10">:</span></h4><ul class="c22 lst-kix_wj1umudc65o3-0 start"><li class="c0"><span class="c3">&lsquo;</span><span class="c3 c6">Name</span><span class="c2">&rsquo; - This column indicates the names of each specific Pokemon</span></li><li class="c0"><span class="c3">&lsquo;</span><span class="c3 c6">Type 1</span><span class="c2">&rsquo; - This is a categorical variable. Each Pokemon belongs to a type of elements, such as Charmander belongs to the fire type which means Charmander can use fire typed skills. There are 18 types which are grass, fire, water, bug, normal, poison, electric, ground, fairy, fighting, psychic, rock, ghost, ice, dragon, dark, steel, and flying.</span></li><li class="c0"><span class="c3 c6">&lsquo;Type 2&rsquo;</span><span class="c2">&nbsp;- This is also a categorical variable. After pokemon&rsquo;s evolution, some Pokemon will obtain another type, such as Charmeleon belongs to both fire and flying after it evolves to Charizard since it will grow wings after the evolution.</span></li><li class="c0"><span class="c3 c6">&lsquo;Total&rsquo;</span><span class="c2">&nbsp;- This column includes the sum of all attributes (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) for each Pokemon. The range of this variable is from 180 to 780.</span></li><li class="c0"><span class="c3 c6">&lsquo;HP&rsquo;</span><span class="c2">&nbsp;- &nbsp;Hit points, also known as health points, is a numerical measurement of health. Hit points will reduce if Pokemon was attacked by other pokemon in a battle. Once pokemon&rsquo;s hit points reached to zero, the pokemon is barred from taking any other actions. The range of this variable is from 1 to 255</span></li><li class="c0"><span class="c3">&lsquo;</span><span class="c3 c6">Attack&rsquo;</span><span class="c2">&nbsp;- Attack is a numerical stat that determines the efficiency of physical attacks, such as a scratch. This stat is only able to determine the power of physical attacks. Special attacks such as fire blast are not able to be determined by an attack. The range of this variable is from 5 to 190.</span></li><li class="c0"><span class="c3 c6">&lsquo;Defense&rsquo;</span><span class="c2">&nbsp;- Defense is a numerical stat that determines the resistance from physical attack. Higher defense will result in lower hit points reduction once the pokemon was under attack by normal attack. The range of this variable is from 5 to 230.</span></li><li class="c0"><span class="c3 c6">&lsquo;Sp.Atk&rsquo;</span><span class="c2">&nbsp;- Sp.Atk is an abbreviation of special attack. Special attack is another numerical stat that determines the amount of damage of special attacks/moves. The range of this variable is from 10 to 194.</span></li><li class="c0"><span class="c3 c6">&lsquo;Sp.Def&rsquo;</span><span class="c2">&nbsp;- Sp.Def is an abbreviation of special defense. It is a numerical stat that determines the resistance from special attacks/moves. The range of this variable is from 20 to 230.</span></li><li class="c0"><span class="c3 c6">&lsquo;Speed&rsquo;</span><span class="c2">&nbsp;- This attribute is used to measure the speed points. Speed points is a numerical variable that is used to determine the order of attacking. Pokemon with higher speed points will be able to attack first in a round and vice versa. The range of this variable is from 5 to 180.</span></li><li class="c0"><span class="c3 c6">&lsquo;Generation&rsquo;</span><span class="c2">&nbsp;- This is a categorical variable which is used to determine the pokemon is from which generation. The dataset only includes the first 6 generations. Thus, the variable is range from 1 to 6.</span></li><li class="c0"><span class="c3 c6">&lsquo;Legendary&rsquo;</span><span class="c2">&nbsp;- This is a Boolean variable used to determine if the Pokemon is Legendary. A small portion of pokemon is called legend pokemon because the rarity of appearance as well as the strong abilities they hold.</span></li></ul><h2 class="c12" id="h.7unmdkphcfll"><span class="c11">&nbsp;Data Collection</span></h2><p class="c1 c8"><span class="c3">The data was collected from the website</span><span class="c3"><a class="c16" href="https://www.pokemon.com/us/pokedex/">&nbsp;</a></span><span class="c3 c5"><a class="c16" href="https://www.pokemon.com/us/pokedex/">pokemon.com</a></span><span class="c3">&nbsp;which includes the stats of 721 pokemon. All stats are base stats which means that any increment from leveling up or from having boosters did not count into this dataset. Each row of this dataset represents one pokemon.</span></p><h2 class="c12" id="h.gtjayov18pq8"><span class="c11">&ldquo;Common Knowledge&rdquo;</span></h2><ul class="c22 lst-kix_9gu4atwo5n7d-0 start"><li class="c0"><span class="c2">Pokemons with Speed points higher than 65 are considered having high speed.</span></li><li class="c0"><span class="c2">Pokemons with HP higher than 65 are considered having high hit points.</span></li><li class="c0"><span class="c2">Pokemons with Attack higher than 75 are considered having high attack strength.</span></li><li class="c0"><span class="c2">Pokemons with Defense higher than 70 are considered having high defensive strength.</span></li><li class="c0"><span class="c2">Pokemons with Sp.Atk higher than 65 are considered having high special attack strength.</span></li><li class="c0"><span class="c2">Pokemons with Sp.Def higher than 70 are considered having high special defensive strength.</span></li><li class="c0"><span class="c2">Pokemons in Dragon category usually have high hit points.</span></li></ul><h2 class="c12" id="h.qzeg0fwrd2lv"><span class="c11">Review of Other Research</span></h2><p class="c1 c8"><span class="c2">There is a machine learning study done by data scientist Yassine Alouini posted on Kaggle, his study focuses on classify the major type (Type 1) of Pokemon in this dataset. The study demonstrated the idea by using different machine learning methods such as logistic regression, XGBoost, Neural network, Random Forests and Tpot method. Firstly, the author split the data into testing and training data. The author starts with a logistic regression, a 24% accuracy was obtained. The second method the author applied was XGboost, by optimizing the hyperparameters with Hyperopt method, the model results a best 7% increase on accuracy. The third method the author tried was random forests which results a 23% accuracy without hyperparameter tuning. The fourth method the author applied was neural network that results a higher accuracy is 26%. The last method he tried, which also best performed, is Tpot that gives a 57% of accuracy. Overall, he concludes that the Tpot is the best classification method for this dataset. However, based on his study, there are also some limitations exist in the study. Since the dataset only include hundreds of observations, one of the limitations is that there is no reason for him to perform neural network or other complicated machine learning methods. Additional observations will be needed to perform a better result.</span></p><p class="c1"><span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p></body></html>
# <hr>

# %% [markdown]
# # Exploratory Analysis of the Data
# Some notes before reading this section:
# * __Ability__ means that the strength of pokemon in each aspect of __HP__,__Attack__, __Defense__, __Sp. Atk__, __Sp. Def__, __Speed__.
# * __Ability Point__ means the point a pokemon get from a perticualr ability (__HP__,__Attack__, __Defense__, __Sp. Atk__, __Sp. Def__, __Speed__)

# %%
# include packages for data analysis
import warnings
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap

# include packages for data modeling
import statsmodels.api as sm
import statsmodels.formula.api as smf

# set the autosave frequency
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %% [markdown]
# ### We will start from exploring the basic information of the dataset we are using, including the following:
# * The head of the data set
# * The shape of the data set
# * The information `.info()` of the data set. This would give us an idea how many columns are numeric and how many are categorical
# * The summary statistics (if avaliable) of each columns

# %% [markdown]
# #### Read the data frame and output the head of the dataframe

# %%
# read the dataset
df = pd.read_csv('Pokemon.csv')
# check the head of the data set
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### Check the shape of the dataframe

# %%
# check the shape of the dataframe
print(df.shape)
# Out:
# (800, 13)

# %% [markdown]
# #### Check the info of the dataframe (type of each column and how many missing values)

# %%
# check the info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# From the above `.info()` summary, we find out the following things
# 1. the column `Type 2` has many missing values. However, from the __Background__ section, we see that by the rule of the game, some of the pokemon does not have a second type, which then lead to the `NaN` values we see. Thus, to deal with this, in the data cleaning section, we must replace the `NaN` values with a specific catgory.
# 2. columns `#` (which is the id of the pokemon), `Generation` should be not be numeric even though they are stored as `int64`. We should fix this issue when we do the data cleaning.

# %% [markdown]
# #### Check the summary statistics of each columns (when a column is meaningful a numerical variable)

# %% [markdown]
# * Some of the columns are numerical values but has no numerical meaning (e.g. '#' and 'generation' column, see the background part for more information). They are not included in the following summary statistics table.

# %%
# check the summary statics of each columns.
df.iloc[:,4:11].describe().round(2)
# Out:
#         Total      HP  Attack  Defense  Sp. Atk  Sp. Def   Speed
# count  800.00  800.00  800.00   800.00   800.00   800.00  800.00
# mean   435.10   69.26   79.00    73.84    72.82    71.90   68.28
# std    119.96   25.53   32.46    31.18    32.72    27.83   29.06
# min    180.00    1.00    5.00     5.00    10.00    20.00    5.00
# 25%    330.00   50.00   55.00    50.00    49.75    50.00   45.00
# 50%    450.00   65.00   75.00    70.00    65.00    70.00   65.00
# 75%    515.00   80.00  100.00    90.00    95.00    90.00   90.00
# max    780.00  255.00  190.00   230.00   194.00   230.00  180.00

# %% [markdown]
# We will then use a boxplot to give a direct representation of the summary statistics. Since the column `Total` is the sum of all points from `HP` column to `Speed` column, we will plot the the column `Total` in one plot and the rest columns in another. We will also give a KDE plot of all ability points (__HP__,__Attack__, __Defense__, __Sp. Atk__, __Sp. Def__, __Speed__) of the pokemons.

# %%
# box plot of the summary statistics (column total)
sns.set_style("whitegrid")
sns.set_palette("Set3")
sns.boxplot(y='Total', data=df,  orient='h').set_title('Box plot of the Total points of pokemons')
plt.show()

# %%
# box plot of column total to columns HP to Speed
sns.boxplot(data=df.iloc[:,5:11],  orient='h').set_title('Box plot of all ability-points of pokemons')
plt.xlabel('points')
plt.show()

# %%
# kde plots.
warnings.simplefilter('ignore')
plt.figure(figsize=(9,6.5))
for i in range(5,11):
    sns.kdeplot(df.iloc[:,i],shade=True)
plt.title('KDE plot of all ability-points of pokemons')
plt.xlabel('points')
plt.ylabel('density')
plt.show()

# %% [markdown]
# From the box plot made above. We see that for each ability point (__HP__,__Attack__, __Defense__, __Sp. Atk__, __Sp. Def__, __Speed__), There are numerous outliers on the right hand side, but there is very few outliers on the left hand side. This means that the distribution of the ability points are right skewed (meaning there is long right tails). Therefore, we can conclude that there are many pokemons with a very strong aspect, but very few pokemons has an extremely weak aspect. This observation, of course, is confirmed by the KDE plot we made. We guess that *legendary* pokemons might contribute to these outliers we see in the distributions (since *legendary* pokemons are known to be more powerful than non-lengendary ones). We will explore this relationship later subsection of our analysis.
#
# Also, we can see that the __HP__ value of the pokemon in general has relatively small variences (even though there is a lot of out liers); the __Attack__, __Sp.Atk__, and __Speed__ of pokemon has relatively large variance. However, despite this relative size of variance, the distribution of all ability points are actaully very similar. We will then use a kernal density estiamtion to plot the distribution of all ability. The KDE plot made can confirm this observation we made from the box plot.

# %% [markdown]
# ### Then, we will do the data cleaning to make the data easier for analysis

# %% [markdown]
# #### Change the `NaN` in the `Type 2` columns as string 'none'
# * Notice that a pokemon may have a second type but it also normal of a pokemon to have only one type. So, instead of representing it as `NaN`, it may be a good idea to give it value 'none'

# %%
# fill the na
pokemon = df.fillna('none')
# check the head
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire    none    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### Change the type of column `#` and column `Generation`

# %%
pokemon['#'] = pokemon['#'].astype(dtype='object')
pokemon['Generation'] = pokemon['Generation'].astype(dtype='object')
# check that we have done everything correctly
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
# #             800 non-null object
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        800 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null object
# Legendary     800 non-null bool
# dtypes: bool(1), int64(7), object(5)
# memory usage: 75.9+ KB

# %% [markdown]
# ### Next, we will explore the relationship laying inside the data

# %% [markdown]
# #### Question 1: It there any relationship between each pairs of the ability points?
# * For example, is there any relationship between `Attack` points and `Sp. Atk` points? Would high values in `Attack` corresponds to low values in `Sp. Atk`?
# * Also, is there any relationship between `HP` and `Defense`? Would high `HP` corresponds to high values in `Defense`?
# * This question will investigate all relationships in the numerical variables

# %%
# produce the pair plot
warnings.simplefilter('ignore')
sns.set()
g = sns.pairplot(pokemon.iloc[:,5:11],diag_kind='kde',diag_kws=dict(shade=True), kind = 'reg')

# %% [markdown]
# To help understanding the pair plot we made, we also make the correlation matrics each ability paris

# %%
# correlation matrix
pokemon.iloc[:,5:11].corr()
# Out:
#                HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# HP       1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %% [markdown]
# From the above plot and correlation matrix, we could see that several abilities of pokemons have relatively strong correlations:
# 1. Sp. Def and Defense has $\rho=0.511$
# 2. Sp. Atk and Sp.Def has $\rho=0.506$
# 3. Speed and Sp.Atk has $\rho=0.473$
# 4. Defense and Attack has $\rho=0.439$
# 5. Attack and HP has $\rho=0.422$
#
# The rest of the correlation is not very strong. In fact, even the pairs I listed above does not have a very high correlation: if we run a linear regression on those pairs, we will get a $R^2 \approx 0.25$ which is not very high.

# %% [markdown]
# #### Question 2: Will the abilities of the legendary pokemon differ from the non-legendary ones?
# * This question will explory a how a categorical varaible can affect the value of some numerical variables
# * We will first look at the total points

# %%
# box plot of total point of legendary pokemon vs. non=legendary pokemon
plt.figure(figsize=(9,6.5))
sns.boxplot(x='Legendary', 
            y='Total', 
            data=pokemon, 
            palette="Set3").set_title('Box plot of the Total points of pokemons (legendary vs. non-legendary)')
plt.show()

# %%
# box plot of ledendary pokemon vs. non-lengendary pokemon in terms of each ability
# first we will melt the data
pmelt = pd.melt(pokemon, 
                id_vars=['Name','Type 1','Type 2','Legendary'], 
                value_vars=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'],
               var_name='Ability', value_name='Points')
print(pmelt.head())
# Out:
#                     Name Type 1  Type 2  Legendary Ability  Points
# 0              Bulbasaur  Grass  Poison      False      HP      45
# 1                Ivysaur  Grass  Poison      False      HP      60
# 2               Venusaur  Grass  Poison      False      HP      80
# 3  VenusaurMega Venusaur  Grass  Poison      False      HP      80
# 4             Charmander   Fire    none      False      HP      39

# %%
# make the plot
plt.figure(figsize=(9,6.5))
sns.boxplot(x='Ability',
            y='Points', 
            data= pmelt,
            hue='Legendary').set_title('Box plot of Each Ability of Pokemons (legendary vs. non-legendary)')
plt.show()

# %% [markdown]
# From the above plot, we can see that in general the legendary pokemons have higher abilities than those of non-legendary pokemons. Since this is true for each of the abilities of pokemons, it is very likely that this difference is significant, and legendary pokemons are indeed more powerful than regular ones.

# %% [markdown]
# #### Question 3: Does the abilities of pokemon from different types (we only consider Type 1 here) differ?
# * This question will explory a how a categorical varaible can affect the value of some numerical variables
# * We will do each ability in the order `Total`, `HP`, `Attack`, `Defense`, `Sp. Atk`, `Sp. Def`, `Speed`.

# %%
# Firstly, we will plot total points
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='Total', data=pokemon).set_title('Total points of different types of pokemon')
plt.show()

# %%
# Seconly, we will plot HP
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='HP', data=pokemon).set_title('HP points of different types of pokemon')
plt.show()

# %%
# Thirdly, we will plot Attack
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='Attack', data=pokemon).set_title('Attack points of different types of pokemon')
plt.show()

# %%
# Forthly, we will plot Defense
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='Defense', data=pokemon).set_title('Defense points of different types of pokemon')
plt.show()

# %%
# Fifthly, we will plot Sp. Atk
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='Sp. Atk', data=pokemon).set_title('Special Attack points of different types of pokemon')
plt.show()

# %%
# Sixthly, we will plot Sp. Def
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='Sp. Def', data=pokemon).set_title('Sepecial Defense points of different types of pokemon')
plt.show()

# %%
# Finally, we will plot Speed
plt.figure(figsize=(12,6))
sns.boxplot(x='Type 1',y='Speed', data=pokemon).set_title('Speed points of different types of pokemon')
plt.show()

# %% [markdown]
# From the above plot, we see that the pokemon of different types indeed have different strengthes and weakness in their abilities:
# 1. Dragon pokemons tend to have a high total ability
# 2. Dragon, Rock, Fighting, and Ground pokemons tend to have relatively strong Attack points
# 3. Steel pokemons tends to have relatively strong Defense points
# 4. Fire, Electric, Psychic, Dragon, and Flying pokemons tend to be strong in their Special Attack. However, Bugs, Normal, Ground, Fighting pokemons are relatively week in Special Attack.
# 5. Flying pokemons have really high speed, but Steel and Fairy pokemons tends to be short in their speeds.
# 6. There is no large differences in HP and Special Defense across different types of pokemons.

# %% [markdown]
# #### Question 4: How does the generation of the pokemon affect their abilities?
# * This question will explory a how a categorical varaible can affect the value of some numerical variables
# * Again, we will do each ability in the order `Total`, `HP`, `Attack`, `Defense`, `Sp. Atk`, `Sp. Def`, `Speed`.

# %%
# plots for 'Total'
plt.figure(figsize=(16,4))
sns.boxplot(x='Generation',y='Total', data=pokemon
            , palette='Blues_d').set_title('Total points of different generations of pokemon')
plt.show()

# plots for'HP', 'Attack', and 'Defense'
_, axis = plt.subplots(1,3, figsize=(16,4))
sns.boxplot(x='Generation',y='HP', data=pokemon,
            ax=axis[0], palette='Blues_d').set_title('HP points of different generations of pokemon')
sns.boxplot(x='Generation',y='Attack', data=pokemon,
            ax=axis[1], palette='Blues_d').set_title('Attack points of different generations of pokemon')
sns.boxplot(x='Generation',y='Defense', data=pokemon,
            ax=axis[2], palette='Blues_d').set_title('Defense points of different generations of pokemon')
plt.show()

# plots for 'Sp. Atk', 'Sp. Def', 'Speed'
_, axis = plt.subplots(1,3, figsize=(16,4))
sns.boxplot(x='Generation',y='Sp. Atk', data=pokemon,
            ax=axis[0], palette='Blues_d').set_title('Sp. Attack points of different generations of pokemon')
sns.boxplot(x='Generation',y='Sp. Def', data=pokemon,
            ax=axis[1], palette='Blues_d').set_title('Sp. Defense points of different generations of pokemon')
sns.boxplot(x='Generation',y='Speed', data=pokemon,
            ax=axis[2], palette='Blues_d').set_title('Speed points of different generations of pokemon')
plt.show()

# %% [markdown]
# From the above plots, we see that the ability of pokemons from each generations are very similar and there is no large variances between each generations.

# %% [markdown]
# #### Question 5: Does the abilities of pokemons get improved if they have a second type (Type 2 is not none)?
# * This question will explory a how a categorical varaible can affect the value of some numerical variables

# %%
# we will first process the data
question5 = pokemon.copy()
question5.loc[question5['Type 2']!='none', 'Type 2'] = 'With a second type'
q5_melt = pd.melt(question5, 
                id_vars=['Name','Type 1','Type 2'], 
                value_vars=['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed'],
                var_name='Ability', value_name='Points')
q5_melt.head()
# Out:
#                     Name Type 1              Type 2 Ability  Points
# 0              Bulbasaur  Grass  With a second type      HP      45
# 1                Ivysaur  Grass  With a second type      HP      60
# 2               Venusaur  Grass  With a second type      HP      80
# 3  VenusaurMega Venusaur  Grass  With a second type      HP      80
# 4             Charmander   Fire                none      HP      39

# %%
# make the plot 
_, axis = plt.subplots(1,2,figsize=(16,8))
sns.boxplot(x='Type 2', 
            y='Total', 
            data=question5, ax = axis[0],
            palette="Set3").set_title('Box plot of the Total points of pokemons \n(with a second type vs. without second type)')

sns.boxplot(x='Ability',
            y='Points', 
            data= q5_melt, ax = axis[1],
            hue='Type 2',
            palette="Set2").set_title('Box plot of Each Ability of Pokemons \n(with a second type vs. without second type)')
plt.show()

# %% [markdown]
# From the above plots, it seems that the abilities of pokemons without a second type is slightly worse than those of pokemons with a second type. However, despite the fact that this differences is uniform across all aspect of the abilities, the difference of abilities between pokemons with or without a second type is fairly small.

# %% [markdown]
# #### Question 6: For each type (Type 1) of pokemon, does new pokemon added differ for each generation?
# * This question will invest how two categorical varaibles will interact with each other
# * We will first create a segmented bar chart for this question
# * We will also find a two-way table for this question.

# %%
# Firstly, we will make the plot according to value count.
pokemon.groupby('Type 1')['Generation']\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True, colormap=ListedColormap(sns.color_palette("RdBu_r",7)), figsize = (12,8))
plt.title("No. of pokemons in each type by different Generations")
plt.show()

# %%
two_way_table_count = pokemon.groupby('Type 1')['Generation']\
    .value_counts().unstack(level=1).fillna(0).astype('int64')
two_way_table_count['Total'] = two_way_table_count.sum(axis = 1)
two_way_table_count.loc['Total'] = two_way_table_count.sum(axis = 0)
two_way_table_count
# Out:
# Generation    1    2    3    4    5   6  Total
# Type 1
# Bug          14   12   12   10   18   3     69
# Dark          0    6    6    3   13   3     31
# Dragon        3    0   12    4    9   4     32
# Electric      9    7    5   12    8   3     44
# Fairy         2    5    0    1    0   9     17
# Fighting      7    2    5    3    7   3     27
# Fire         14    8    8    5    9   8     52
# Flying        0    0    0    0    2   2      4
# Ghost         4    1    5    7    5  10     32
# Grass        13    9   13   15   15   5     70
# Ground        8    3    7    4   10   0     32
# Ice           2    4    7    3    6   2     24
# Normal       24   15   18   18   19   4     98
# Poison       14    1    3    6    2   2     28
# Psychic      11    7   12    8   14   5     57
# Rock         10    5    8    6    6   9     44
# Steel         0    3   12    3    4   5     27
# Water        31   18   27   13   18   5    112
# Total       166  106  160  121  165  82    800

# %%
# we then create the plot using the percentage values
pokemon.groupby('Type 1')['Generation']\
    .value_counts(normalize = True)\
    .unstack(level=1)\
    .plot.bar(stacked=True, colormap=ListedColormap(sns.color_palette("Paired", 10)), figsize = (12,8), legend = False)
plt.title("Prop. of pokemons in each type by different Generations")
plt.legend(bbox_to_anchor=(1, 1), loc=2, title="Generation")
plt.show()

# %%
two_way_table_prop = pokemon.groupby('Type 1')['Generation']\
    .value_counts(normalize=True).unstack(level=1).fillna(0)
two_way_table_prop['Total'] = two_way_table_prop.sum(axis = 1)
two_way_table_prop.round(3)
# Out:
# Generation      1      2      3      4      5      6  Total
# Type 1
# Bug         0.203  0.174  0.174  0.145  0.261  0.043    1.0
# Dark        0.000  0.194  0.194  0.097  0.419  0.097    1.0
# Dragon      0.094  0.000  0.375  0.125  0.281  0.125    1.0
# Electric    0.205  0.159  0.114  0.273  0.182  0.068    1.0
# Fairy       0.118  0.294  0.000  0.059  0.000  0.529    1.0
# Fighting    0.259  0.074  0.185  0.111  0.259  0.111    1.0
# Fire        0.269  0.154  0.154  0.096  0.173  0.154    1.0
# Flying      0.000  0.000  0.000  0.000  0.500  0.500    1.0
# Ghost       0.125  0.031  0.156  0.219  0.156  0.312    1.0
# Grass       0.186  0.129  0.186  0.214  0.214  0.071    1.0
# Ground      0.250  0.094  0.219  0.125  0.312  0.000    1.0
# Ice         0.083  0.167  0.292  0.125  0.250  0.083    1.0
# Normal      0.245  0.153  0.184  0.184  0.194  0.041    1.0
# Poison      0.500  0.036  0.107  0.214  0.071  0.071    1.0
# ...

# %% [markdown]
# From the the result above, we can see that the number of pokemons belong to each type has very large differences. Varying from more than 100 (Type water) to only 4 (Flying). Also, for each type (Type 1) of pokemon, the number of new pokemons added differ can be very different across each generation. This is evident due to the uneven segments shown in both plots we have made above. This is also confirmed with the two way tables, where each row has very different values.

# %% [markdown]
# #### Question 7: For each type (Type 1) of pokemon, does does the proportions of legendary pokemon differs?
# * This question will invest how two categorical varaibles will interact with each other
# * We will create a segmented bar chart for this question
# * We will also find a two-way table for this question.

# %%
# we create the plot using the percentage values
pokemon.groupby('Type 1')['Legendary']\
    .value_counts(normalize = True)\
    .unstack(level=1)\
    .plot.bar(stacked=True, colormap=ListedColormap(sns.color_palette("Paired", 5)), figsize = (12,8), legend = False)
plt.title("Prop. of Legdendary pokemons in each type")
plt.legend(bbox_to_anchor=(1, 1), loc=2, title="Legendary")
plt.show()

# %%
# make the two way table
two_way_table_prop = question5.groupby('Type 1')['Legendary']\
    .value_counts(normalize=True).unstack(level=1).fillna(0)
two_way_table_prop['Total'] = two_way_table_prop.sum(axis = 1)
two_way_table_prop.round(2).T
# Out:
# Type 1     Bug  Dark  Dragon  Electric  Fairy  Fighting  Fire  Flying  Ghost  \
# Legendary
# False      1.0  0.94    0.62      0.91   0.94       1.0   0.9     0.5   0.94
# True       0.0  0.06    0.38      0.09   0.06       0.0   0.1     0.5   0.06
# Total      1.0  1.00    1.00      1.00   1.00       1.0   1.0     1.0   1.00
#
# Type 1     Grass  Ground   Ice  Normal  Poison  Psychic  Rock  Steel  Water
# Legendary
# False       0.96    0.88  0.92    0.98     1.0     0.75  0.91   0.85   0.96
# True        0.04    0.12  0.08    0.02     0.0     0.25  0.09   0.15   0.04
# Total       1.00    1.00  1.00    1.00     1.0     1.00  1.00   1.00   1.00

# %% [markdown]
# From the the result above, we can see that for each type (Type 1) of pokemon, the proportions of lengendary pokemons differ can be very different across each type. This is evident due to the uneven segments shown in the plot above we have made. This is also confirmed with the two way tables, where for each row, the result for each Type of pokemon is very different.
#
# <p class="c1 c4"><span class="c2"></span></p><p class="c1"><span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p>
#
# <hr> <!-- add a sperating line -->

# %% [markdown]
# # Data Modeling

# %% [markdown]
# ## Import all required packages.
#
# We decided to perform the random forest classification for classify pokemon legendary status.

# %%
# %%capture
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import f1_score
from tpot import TPOTClassifier

# %%
pokemon = pd.read_csv("Pokemon.csv")
print(pokemon.head())
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## Data transformation before performing the model.
#
# In order to perform the random forest classification, we need to encode string variables into integers. For doing so, we use the package called LabelEncoder to perform the certain transformation

# %%
for column in pokemon['Type 1']:
    if pokemon['Type 1'].dtype == type(object):
        le = LabelEncoder()
        pokemon['Type 1'] = le.fit_transform(pokemon['Type 1'])
        
pokemon = pokemon.replace(np.nan, 'No Type 2', regex=True)
        
for column in pokemon['Type 2']:
    if pokemon['Type 2'].dtype == type(object):
        le = LabelEncoder()
        pokemon['Type 2'] = le.fit_transform(pokemon['Type 2'])
        
print(pokemon.head())
# Out:
#    #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur       9      14    318  45      49       49
# 1  2                Ivysaur       9      14    405  60      62       63
# 2  3               Venusaur       9      14    525  80      82       83
# 3  3  VenusaurMega Venusaur       9      14    625  80     100      123
# 4  4             Charmander       6      12    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## Spliting Data
#
# For performing the random forest classification, we firstly split data into training and testing data. Also, since the attribute 'Total' is the composition of all other ability scores, we decided to drop all other scores and keep 'Total' instead.

# %%
X=pokemon[['Type 1', 'Type 2','Total', 'Generation']]  # Features
y=pokemon['Legendary']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=457682)

# %%
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=30,max_depth=3)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## Test of Overfitting by Cross Validation
# * We run a 10 fold cross validation to test if we are overfitting

# %%
# output the training error
print("Accuracy:",metrics.accuracy_score(y_train, clf.predict(X_train)))

# Perform a 10-fold cross validation
print("Cross Validation Score: ", np.mean(cross_val_score(clf, X_train, y_train, cv=10)))
# Out:
# Accuracy: 0.9553571428571429
# Cross Validation Score:  0.9462200956937797

# %%
# accruacy on the test set
y_pred=clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9416666666666667

# %% [markdown]
# After performing random forest classification, our accuracy of classification is 95.5%. Since this score is very close to the cross validation score of 0.946, there is no overfitting in our model.

# %%
# Create a plot of significance of each variable.
rfc = RandomForestClassifier()
rfc.fit(X, y)
importances = pd.DataFrame({'FEATURE':X.columns,'IMPORTANCE':np.round(rfc.feature_importances_,3)})
importances = importances.sort_values('IMPORTANCE',ascending=False).set_index('FEATURE')

print(importances)
importances.plot.bar(figsize = (12,8), title = "Importance Plot")
#plt.savefig('importplot.png')
plt.show()
# Out:
#             IMPORTANCE
# FEATURE
# Total            0.682
# Generation       0.114
# Type 1           0.109
# Type 2           0.096

# %% [markdown]
# We have also created a importance plot to visualize the importance of each variables. The importance of 'Total' is nearly 0.7 that beget it as the most important variable in this model. The rest of variables are not as important as 'Total'.

# %% [markdown]
# ## F1 Score

# %%
print(f1_score(y_test, y_pred, average="macro"))
# Out:
# 0.8744113029827315

# %% [markdown]
# Due to the restriction of inbalanced legendary status, we used the macro f1 score to replace the accuracy which does not take the inbalance into account.
#
# $ \text{Macro average precision} = (P1+P2)/2 $
#
# $ \text{Macro average recall} = (R1+R2)/2 $
#
# ${\displaystyle F_{1}=\left({\frac {\mathrm {recall} ^{-1}+\mathrm {precision} ^{-1}}{2}}\right)^{-1}=2\cdot {\frac {\mathrm {precision} \cdot \mathrm {recall} }{\mathrm {precision} +\mathrm {recall} }}}$

# %% [markdown]
# ## Pipeline optimization
#
# For enhancing our model, we decided to use the method TPOT classifier from package TPOT. The function will create numerous pipelines and keep compositing different models until your designated termination. Then the function will return a final composite model to us with a optimized accuracy. Also, we have used macro f1 score as the criteria.

# %%
# Use package TPOT to perform a pipeline_optimizer in order to enchance the model
pipeline_optimizer = TPOTClassifier()
pipeline_optimizer = TPOTClassifier(generations=10, population_size=80, cv=5,n_jobs=-1,
                                    random_state=31415, verbosity=2, scoring = 'f1_macro')

# %%
warnings.simplefilter('ignore')
pipeline_optimizer.fit(X_train, y_train)
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.8636658833855385
# Generation 2 - Current best internal CV score: 0.8636658833855385
# Generation 3 - Current best internal CV score: 0.8726742681937181
# Generation 4 - Current best internal CV score: 0.8726742681937181
# Generation 5 - Current best internal CV score: 0.884720856164957
# Generation 6 - Current best internal CV score: 0.8958400768485125
# Generation 7 - Current best internal CV score: 0.8958400768485125
# Generation 8 - Current best internal CV score: 0.8958400768485125
# Generation 9 - Current best internal CV score: 0.9006232314896792
# Generation 10 - Current best internal CV score: 0.9006232314896792
#
# Best pipeline: DecisionTreeClassifier(GradientBoostingClassifier(input_matrix, learning_rate=0.5, max_depth=1, max_features=0.8, min_samples_leaf=14, min_samples_split=3, n_estimators=100, subsample=0.9000000000000001), criterion=entropy, max_depth=10, min_samples_leaf=19, min_samples_split=12)
# ...

# %%
print(pipeline_optimizer.score(X_test, y_test))
# Out:
# 0.9361396413176521

# %%
print("Accuracy:",metrics.accuracy_score(y_test, pipeline_optimizer.predict(X_test)))
# Out:
# Accuracy: 0.9791666666666666

# %% [markdown]
# The tpot optimization can improve the test performance by some degree, but it can significantly imporve the f1-score from 0.88 to about 0.95.

# %% [markdown]
# ## Conclusion:
# After performing the TPOT classification, we can see the accuracy did not enchance through our new composite model. We suspect that the reason behind this problem is our data still consists inbalanced legendary status. Our testing data consists 240 observations, but only 22 of them are legendary. Due to the restriction of insufficient data recorded, we could not enlarge the amount of legendary pokemons. Our model is best performed with this extreme inbalanced dataset. The final f1 score is good enough for us to indicate the equal imporatance for both classes and we do not need to overlook the result.

# %% [markdown]
# ## Limitation:
# - As mentioned above, one of the limitation of our study is the insufficient observations of legendary pokemons.
# - Besides the insufficient legendary pokemons, we also need more observations for both legendary and non-legendary pokemons for performing a better result of random forest classification.
# - we might need more essential variables in this dataset, such as species strength.
# - As mentioned in the background, the dataset includes both original status and evolved status of each pokemon. Pokemon's ability will enhance significantly by evolution. Therefore, it seems like the dataset included some unuseful information for classification since unevolved pokemons tend to have low ability scores.
# - We also suspect that the random forest might not be the best model for this type of classification.
#
# <p class="c1 c4"><span class="c2"></span></p><p class="c1"><span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span></p>
#
# <hr> <!-- add a sperating line -->
